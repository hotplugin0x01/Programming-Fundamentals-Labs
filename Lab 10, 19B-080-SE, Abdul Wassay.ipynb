# %% [markdown]
# # 19B-080-SE, Abdul Wassay
# # Section B, Lab 10

# %% [markdown]
# # Q.01

# %%
from tkinter import *
window = Tk()
window.geometry("300x540")
window.resizable(0,10)
window.title(" Scientific Calculator")
window.configure(background='grey')

def btn_click(item):
    global expression
    expression = expression+str(item)
    input_text.set(expression)
def btn_clear():
    global expression
    expression = ""
    input_text.set("")
def btn_equal():
    global expression
    result = str(eval(expression))
    input_text.set(result)
    expression = ""
expression = ""
input_text = StringVar()

input_frame = Frame(window, width = 312, height = 50, bd = 4,highlightthickness = 1,bg = "grey")
input_frame.pack(side = TOP)

input_field = Entry(input_frame, font = ('arial',18,'bold'),
                   textvariable = input_text,width = 50, bg = "grey",bd = 0, justify = LEFT)
input_field.pack(ipady = 10)
btns_frame = Frame(window,width = 480,height = 372.5,bg = 'black')
btns_frame.pack()

#---------------------------First Row-------------------------------

bracketOpen = Button(btns_frame,text = "(",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("(")).grid(row = 0, column = 1,padx = 1,pady = 1)

bracketClose = Button(btns_frame,text = ")",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click(")")).grid(row = 0, column = 2,padx = 1,pady = 1)
cbroot = Button(btns_frame,text = "∛",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("∛")).grid(row = 0, column = 3,padx = 1,pady = 1)

clear = Button(btns_frame,text = "C",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_clear()).grid(row = 0,column = 4, padx = 1, pady = 1)

#---------------------------Second Row-------------------------------

sinh =Button(btns_frame,text = "sinh",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("sinh")).grid(row = 2, column = 1,padx = 1,pady = 1)
cosh = Button(btns_frame,text = "cosh",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("cosh")).grid(row = 2, column = 2,padx = 1,pady = 1)
tanh = Button(btns_frame,text = "tanh",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("tanh")).grid(row = 2, column = 3,padx = 1,pady = 1)
exp = Button(btns_frame,text = "exp",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("exp")).grid(row = 2,column = 4, padx = 1, pady = 1)

#---------------------------Third Row-------------------------------

sin= Button(btns_frame,text = "sin",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("sin")).grid(row = 3, column = 1,padx = 1,pady = 1)
cos = Button(btns_frame,text = "cos",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("cos")).grid(row = 3, column = 2,padx = 1,pady = 1)
tan = Button(btns_frame,text = "tan",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("tan")).grid(row = 3, column = 3,padx = 1,pady = 1)
divide = Button(btns_frame,text = "/",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("/")).grid(row = 3, column = 4,padx = 1,pady = 1)


#---------------------------Fourth Row-------------------------------

seven = Button(btns_frame,text = "7",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("7")).grid(row = 4, column = 1,padx = 1,pady = 1)
eight = Button(btns_frame,text = "8",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("8")).grid(row = 4, column = 2,padx = 1,pady = 1)
nine = Button(btns_frame,text = "9",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("9")).grid(row = 4, column = 3,padx = 1,pady = 1)
multiply = Button(btns_frame,text = "*",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("*")).grid(row = 4, column = 4,padx = 1,pady = 1)

#---------------------------fifth Row-------------------------------

fourth = Button(btns_frame,text = "4",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("4")).grid(row = 5, column = 1,padx = 1,pady = 1)
fifth = Button(btns_frame,text = "5",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("5")).grid(row = 5, column = 2,padx = 1,pady = 1)
sixth = Button(btns_frame, text = "6",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("6")).grid(row = 5,column = 3, padx = 1, pady = 1)
minus = Button(btns_frame,text = "-",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("-")).grid(row = 5, column = 4,padx = 1,pady = 1)

#---------------------------Sixth Row-----------------------------------
one = Button(btns_frame,text = "1",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("1")).grid(row = 6, column = 1,padx = 1,pady = 1)
two = Button(btns_frame,text = "2",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("2")).grid(row = 6, column = 2,padx = 1,pady = 1)
three = Button(btns_frame, text = "3",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("3")).grid(row = 6,column = 3, padx = 1, pady = 1)
plus = Button(btns_frame,text = "+",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("+")).grid(row = 6, column = 4,padx = 1,pady = 1)

#---------------------------Seventh Row-------------------------------

per = Button(btns_frame,text = "%",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("%")).grid(row = 7, column = 1,padx = 1,pady = 1)
zero = Button(btns_frame,text = "0",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("0")).grid(row = 7, column = 2,padx = 1,pady = 1)
decimal = Button(btns_frame, text = ".",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click(".")).grid(row = 7,column = 3, padx = 1, pady = 1)
equal = Button(btns_frame,text = "=",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("=")).grid(row = 7, column = 4,padx = 1,pady = 1)

#---------------------------Eight Row-------------------------------

sininverse = Button(btns_frame,text = "sin-1",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("sin-1")).grid(row = 8, column = 1,padx = 1,pady = 1)
cosinverse = Button(btns_frame,text = "cos-1",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("cos-1")).grid(row = 8, column = 2,padx = 1,pady = 1)
taninverse = Button(btns_frame, text = "tan-1",fg = "white",width = 10,height=3,bd = 0,
               bg = "grey",cursor = "hand2",command = lambda:
               btn_click("tan-1")).grid(row = 8,column = 3, padx = 1, pady = 1)
power = Button(btns_frame,text = "^",fg = "white",width = 10,height = 3,bd = 0,
              bg = "grey", cursor = "hand2", command = lambda:
              btn_click("^")).grid(row = 8, column = 4,padx = 1,pady = 1)



window.mainloop()

# %% [markdown]
# # Q.02

# %%
from tkinter import*
#------------------------Setting Window------------------------------------------
root = Tk()
root.geometry("800x600")
root.resizable(0,0)
root.title("SUBWAY SYSTEM") 
root.configure(background='grey')

#------------------------Setting Frames------------------------------------------
Tops = Frame(root,bg="grey",width = 1600,height=50,relief=SUNKEN)
Tops.pack(side=TOP)

f1 = Frame(root,width = 800,height=800,relief=SUNKEN,bd=5, bg="grey")
f1.pack(side=LEFT)

#------------------------Setting Heading------------------------------------------
lblinfo = Label(Tops, font=( 'arial' ,40, 'bold' ),text="SUBWAY",fg="BlacK",bd=10, relief='solid', bg='grey')
lblinfo.grid(row=2,column=2)

#------------------------Declaring all variables------------------------------------------
rand = IntVar()
Fries = IntVar()
Largefries = IntVar()
Burger = IntVar()
Filet = IntVar()
Subtotal = IntVar()
Total = IntVar()
Service_Charge = IntVar()
Drinks = IntVar()
Tax = IntVar()
cost = IntVar()
Cheese_burger = IntVar()
Cheesy_Roll=IntVar()
Crunchy_Burger=IntVar()
Crunchy_Roll=IntVar()
Zinger_Burger=IntVar()
Twister_Roll=IntVar()
Pizza_Fries=IntVar()

#--------------------------------Oder No------------------------------------------
lblreference = Label(f1, font=( 'arial' ,14, 'bold' ),text="Order No.",fg="White",bg="grey",anchor='w')
lblreference.grid(row=0,column=0)
txtreference = Entry(f1,font=('ariel' ,14,'bold'), textvariable=rand , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtreference.grid(row=0,column=1)

#--------------------------------Fries------------------------------------------
lblfries = Label(f1, font=( 'arial' ,14, 'bold' ),text="Fries Meal",fg="White",bg="grey",anchor='w')
lblfries.grid(row=1,column=0)
txtfries = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Fries , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtfries.grid(row=1,column=1)

#--------------------------------Lunch------------------------------------------
lblLargefries = Label(f1, font=( 'arial' ,14, 'bold' ),text="Lunch Meal",fg="White",bg="grey",anchor='w')
lblLargefries.grid(row=2,column=0)
txtLargefries = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Largefries , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtLargefries.grid(row=2,column=1)

#--------------------------------Burger------------------------------------------
lblburger = Label(f1, font=( 'arial' ,14, 'bold' ),text="Burger Meal",fg="White",bg="grey",anchor='w')
lblburger.grid(row=3,column=0)
txtburger = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Burger , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtburger.grid(row=3,column=1)

#--------------------------------Pizza------------------------------------------
lblFilet = Label(f1, font=( 'arial' ,14, 'bold' ),text="Pizza Meal",fg="White",bg="grey",anchor='w')
lblFilet.grid(row=4,column=0)
txtFilet = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Filet , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtFilet.grid(row=4,column=1)

#--------------------------------Cheese Burger------------------------------------------
lblCheese_burger = Label(f1, font=( 'arial' ,14, 'bold' ),text="Cheese burger",fg="White",bg="grey",anchor='w')
lblCheese_burger.grid(row=5,column=0)
txtCheese_burger = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Cheese_burger , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtCheese_burger.grid(row=5,column=1)

#--------------------------------------------------------------------------------------
lblCheesy_Roll = Label(f1, font=( 'arial' ,14, 'bold' ),text="Cheesy Roll",fg="White",bg="grey",anchor='w')
lblCheesy_Roll.grid(row=6,column=0)
txtCheesy_Roll = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Cheesy_Roll , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtCheesy_Roll.grid(row=6,column=1)

lblCrunchy_Burger = Label(f1, font=( 'arial' ,14, 'bold' ),text="Crunchy Burger",fg="White",bg="grey",anchor='w')
lblCrunchy_Burger.grid(row=7,column=0)
txtCrunchy_Burger = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Crunchy_Burger , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtCrunchy_Burger.grid(row=7,column=1)

#--------------------------------Roll------------------------------------------
lblCrunchy_Roll = Label(f1, font=( 'arial' ,14, 'bold' ),text="Crunchy Roll",fg="White",bg="grey",anchor='w')
lblCrunchy_Roll.grid(row=8,column=0)
txtCrunchy_Roll = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Crunchy_Roll , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtCrunchy_Roll.grid(row=8,column=1)

#--------------------------------Twister roll------------------------------------------
lblTwister_Roll = Label(f1, font=( 'aria' ,14, 'bold' ),text="Twister Roll",fg="White",bg="grey",anchor='w')
lblTwister_Roll.grid(row=0,column=2)
txtTwister_Roll = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Twister_Roll , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtTwister_Roll.grid(row=0,column=3)

#--------------------------------Pizza Fries------------------------------------------
lblPizza_Fries = Label(f1, font=( 'arial' ,14, 'bold' ),text="Pizza Fries",fg="White",bg="grey",anchor='w')
lblPizza_Fries.grid(row=1,column=2)
txtPizza_Fries = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Pizza_Fries , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtPizza_Fries.grid(row=1,column=3)

#--------------------------------Zinger------------------------------------------
lblZinger_Burger = Label(f1, font=( 'arial' ,14, 'bold' ),text="Zinger Burger",fg="White",bg="grey",anchor='w')
lblZinger_Burger.grid(row=2,column=2)
txtZinger_Burger = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Zinger_Burger , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtZinger_Burger.grid(row=2,column=3)

#--------------------------------Drinks------------------------------------------
lblDrinks = Label(f1, font=( 'arial' ,14, 'bold' ),text="Drinks",fg="White",bg="grey",anchor='w')
lblDrinks.grid(row=3,column=2)
txtDrinks = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Drinks , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtDrinks.grid(row=3,column=3)

#--------------------------------Cost------------------------------------------
lblcost = Label(f1, font=( 'arial' ,14, 'bold' ),text="Cost",fg="White",bg="grey",anchor='w')
lblcost.grid(row=4,column=2)
txtcost = Entry(f1,font=('ariel' ,14,'bold'), textvariable=cost , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtcost.grid(row=4,column=3)

#--------------------------------Charges------------------------------------------
lblService_Charge = Label(f1, font=( 'arial' ,14, 'bold' ),text="Service Charge",fg="White",bg="grey",anchor='w')
lblService_Charge.grid(row=5,column=2)
txtService_Charge = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Service_Charge , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtService_Charge.grid(row=5,column=3)

#--------------------------------Tax------------------------------------------
lblTax = Label(f1, font=( 'arial' ,14, 'bold' ),text="Tax",fg="White",bg="grey",anchor='w')
lblTax.grid(row=6,column=2)
txtTax = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Tax , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtTax.grid(row=6,column=3)

#--------------------------------Sub total------------------------------------------
lblSubtotal = Label(f1, font=( 'arial' ,14, 'bold' ),text="Subtotal",fg="White",bg="grey",anchor='w')
lblSubtotal.grid(row=7,column=2)
txtSubtotal = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Subtotal , bd=3,insertwidth=4,bg="grey" ,justify='right')
txtSubtotal.grid(row=7,column=3)

#--------------------------------Total------------------------------------------
lblTotal = Label(f1, font=( 'arial' ,14, 'bold' ),text="Total",fg="White",bg="grey",anchor='w')
lblTotal.grid(row=8,column=2)
txtTotal = Entry(f1,font=('ariel' ,14,'bold'), textvariable=Total , bd=6,insertwidth=4,bg="grey" ,justify='right')
txtTotal.grid(row=8,column=3)

#-----------------------------------------buttons------------------------------------------
btnTotal=Button(f1,padx=16,pady=8, fg="white",font=('ariel' ,12,'bold'),width=10, text="TOTAL", bg="grey")
btnTotal.grid(row=10, column=1)

btnreset=Button(f1,padx=16,pady=8, fg="white",font=('ariel' ,12,'bold'),width=10, text="RESET", bg="grey")
btnreset.grid(row=10, column=2)

btnexit=Button(f1,padx=16,pady=8, fg="white",font=('ariel' ,12,'bold'),width=10, text="EXIT", bg="grey")
btnexit.grid(row=10, column=3)

#--------------------------------Main loop------------------------------------------
root.mainloop()
