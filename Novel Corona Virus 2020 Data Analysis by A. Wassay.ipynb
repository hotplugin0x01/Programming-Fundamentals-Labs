# %% [markdown]
# # Exercise on Kaggle Dataset

# %% [markdown]
# ## NCororna Virus Analysis

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt 
file_path = os.path.abspath('../Lab 15/')
try:
    train = pd.read_csv(file_path+'/ncov_2019_data.csv')
    print('File Read Successfully')
except:
    print('Error Found')
# Out:
# File Read Successfully

# %%
train.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
train.shape
# Out:
# (770, 8)

# %%
train.dtypes
# Out:
# Sno                 int64
# Date               object
# Province/State     object
# Country            object
# Last Update        object
# Confirmed         float64
# Deaths            float64
# Recovered         float64
# dtype: object

# %%
categorical_var = train.dtypes.loc[train.dtypes=='object'].index
print(categorical_var)
# Out:
# Index(['Date', 'Province/State', 'Country', 'Last Update'], dtype='object')

# %%
train[categorical_var].apply(lambda x:len(x.unique()))
# Out:
# Date               14
# Province/State     57
# Country            32
# Last Update       122
# dtype: int64

# %%
x = train['Recovered'].unique()
len(x)
# Out:
# 43

# %%
train['Country'].value_counts()
# Out:
# Mainland China          398
# US                       60
# China                    34
# Australia                32
# Canada                   20
# South Korea              14
# Japan                    14
# Thailand                 14
# Hong Kong                13
# Vietnam                  13
# Macau                    13
# Taiwan                   13
# Singapore                13
# Malaysia                 12
# France                   12
# Nepal                    11
# Germany                   9
# Cambodia                  9
# Sri Lanka                 9
# Finland                   7
# Philippines               7
# United Arab Emirates      7
# Italy                     6
# India                     6
# Sweden                    5
# UK                        5
# Russia                    5
# Spain                     5
# Mexico                    1
# Belgium                   1
# Ivory Coast               1
# Brazil                    1
# Name: Country, dtype: int64

# %%
train.boxplot(column='Deaths',by='Recovered')

# %%
c = pd.crosstab(train['Country'],train['Date'],margins=True) 
c
# Out:
# Date                  01/22/2020 12:00:00  01/23/2020 12:00:00  \
# Country
# Australia                               0                    1
# Belgium                                 0                    0
# Brazil                                  0                    1
# Cambodia                                0                    0
# Canada                                  0                    0
# China                                  34                    0
# Finland                                 0                    0
# France                                  0                    0
# Germany                                 0                    0
# Hong Kong                               0                    1
# India                                   0                    0
# Italy                                   0                    0
# Ivory Coast                             0                    0
# Japan                                   1                    1
# ...

# %%
train.plot('Confirmed','Deaths',kind='Scatter', grid=True, title='Confirmed Cases vs. Deaths')
